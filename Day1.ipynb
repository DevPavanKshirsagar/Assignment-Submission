# %% [raw]
# RAINBOW

# %%
print("LETS UPGRADE")
# Out:
# LETS UPGRADE

# %%
cost_price = float(input())
sell_price = float(input())

if sell_price > cost_price :
    print("Profit")
    
elif  sell_price < cost_price  :
    print("Loss")
    
else :
    print("Neither")
# Out:
# 10
# 10
# Neither

# %%
euro = int(input())
rupees = euro * 80
print(rupees)
# Out:
# 5
# 400
